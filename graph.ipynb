# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
rawdata = np.genfromtxt("computepass.csv", delimiter=",", skip_header=1).T

ang = rawdata[0]
rcs = rawdata[1]

# %%
plt.semilogy()

plt.plot(ang, rcs)

plt.show()
